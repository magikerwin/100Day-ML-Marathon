# %% [markdown]
# ## 範例重點
# ### 學習在模型開始前檢查各個環節
# 1. 是否有 GPU 資源
# 2. 將前處理轉為函式，統一處理訓練、驗證與測試集
# 3. 將超參數變數化，易於重複使用函式、模型等

# %%
## 確認硬體資源 (如果你是在 Linux, 若是在 Windows, 請參考 https://blog.csdn.net/idwtwt/article/details/78017565)
# !nvidia-smi

# %%
import os
from tensorflow import keras

# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 6s 120us/sample - loss: 1.9334 - accuracy: 0.3023 - val_loss: 1.7725 - val_accuracy: 0.3699
# Epoch 2/100
# 50000/50000 [==============================] - 6s 114us/sample - loss: 1.7111 - accuracy: 0.3871 - val_loss: 1.7070 - val_accuracy: 0.4005
# Epoch 3/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 1.6329 - accuracy: 0.4167 - val_loss: 1.6177 - val_accuracy: 0.4264
# Epoch 4/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 1.5683 - accuracy: 0.4399 - val_loss: 1.6173 - val_accuracy: 0.4225
# Epoch 5/100
# 50000/50000 [==============================] - 6s 113us/sample - loss: 1.5250 - accuracy: 0.4536 - val_loss: 1.5471 - val_accuracy: 0.4490
# Epoch 6/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 1.4783 - accuracy: 0.4737 - val_loss: 1.5197 - val_accuracy: 0.4589
# Epoch 7/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 1.4434 - accuracy: 0.4838 - val_loss: 1.4872 - val_accuracy: 0.4655
# Epoch 8/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 1.4289 - accuracy: 0.4902 - val_loss: 1.4978 - val_accuracy: 0.4746
# Epoch 9/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 1.3909 - accuracy: 0.5037 - val_loss: 1.4423 - val_accuracy: 0.4852
# Epoch 10/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 1.3713 - accuracy: 0.5141 - val_loss: 1.4163 - val_accuracy: 0.4958
# Epoch 11/100
# 50000/50000 [==============================] - 6s 110us/sample - loss: 1.3450 - accuracy: 0.5224 - val_loss: 1.4553 - val_accuracy: 0.4756
# Epoch 12/100
# 50000/50000 [==============================] - 6s 112us/sample - loss: 1.3188 - accuracy: 0.5297 - val_loss: 1.4498 - val_accuracy: 0.4869
# Epoch 13/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 1.2931 - accuracy: 0.5390 - val_loss: 1.4909 - val_accuracy: 0.4782
# Epoch 14/100
# 50000/50000 [==============================] - 6s 110us/sample - loss: 1.2665 - accuracy: 0.5468 - val_loss: 1.4074 - val_accuracy: 0.5071
# Epoch 15/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 1.2515 - accuracy: 0.5542 - val_loss: 1.4044 - val_accuracy: 0.5004
# Epoch 16/100
# 50000/50000 [==============================] - 5s 102us/sample - loss: 1.2241 - accuracy: 0.5623 - val_loss: 1.4065 - val_accuracy: 0.5061
# Epoch 17/100
# 50000/50000 [==============================] - 5s 102us/sample - loss: 1.2062 - accuracy: 0.5693 - val_loss: 1.3870 - val_accuracy: 0.5139
# Epoch 18/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 1.1829 - accuracy: 0.5787 - val_loss: 1.3919 - val_accuracy: 0.5145
# Epoch 19/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 1.1689 - accuracy: 0.5842 - val_loss: 1.3693 - val_accuracy: 0.5178
# Epoch 20/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 1.1368 - accuracy: 0.5978 - val_loss: 1.4059 - val_accuracy: 0.5079
# Epoch 21/100
# 50000/50000 [==============================] - 5s 102us/sample - loss: 1.1246 - accuracy: 0.6012 - val_loss: 1.3717 - val_accuracy: 0.5262
# Epoch 22/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 1.1084 - accuracy: 0.6061 - val_loss: 1.3864 - val_accuracy: 0.5206
# Epoch 23/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 1.0907 - accuracy: 0.6100 - val_loss: 1.3686 - val_accuracy: 0.5310
# Epoch 24/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 1.0597 - accuracy: 0.6226 - val_loss: 1.4750 - val_accuracy: 0.4981
# Epoch 25/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 1.0530 - accuracy: 0.6234 - val_loss: 1.3842 - val_accuracy: 0.5295
# Epoch 26/100
# 50000/50000 [==============================] - 6s 112us/sample - loss: 1.0190 - accuracy: 0.6366 - val_loss: 1.3844 - val_accuracy: 0.5319
# Epoch 27/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 1.0101 - accuracy: 0.6392 - val_loss: 1.4634 - val_accuracy: 0.5136
# Epoch 28/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 0.9935 - accuracy: 0.6453 - val_loss: 1.4106 - val_accuracy: 0.5303
# Epoch 29/100
# 50000/50000 [==============================] - 6s 116us/sample - loss: 0.9751 - accuracy: 0.6502 - val_loss: 1.4241 - val_accuracy: 0.5241
# Epoch 30/100
# 50000/50000 [==============================] - 6s 115us/sample - loss: 0.9597 - accuracy: 0.6569 - val_loss: 1.4192 - val_accuracy: 0.5241
# Epoch 31/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.9498 - accuracy: 0.6600 - val_loss: 1.4518 - val_accuracy: 0.5207
# Epoch 32/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.9331 - accuracy: 0.6673 - val_loss: 1.4290 - val_accuracy: 0.5371
# Epoch 33/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.9079 - accuracy: 0.6739 - val_loss: 1.4852 - val_accuracy: 0.5178
# Epoch 34/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.8867 - accuracy: 0.6835 - val_loss: 1.4921 - val_accuracy: 0.5185
# Epoch 35/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.8761 - accuracy: 0.6870 - val_loss: 1.4879 - val_accuracy: 0.5298
# Epoch 36/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.8678 - accuracy: 0.6898 - val_loss: 1.5735 - val_accuracy: 0.5122
# Epoch 37/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 0.8570 - accuracy: 0.6950 - val_loss: 1.5303 - val_accuracy: 0.5096
# Epoch 38/100
# 50000/50000 [==============================] - 6s 110us/sample - loss: 0.8224 - accuracy: 0.7070 - val_loss: 1.5600 - val_accuracy: 0.5188
# Epoch 39/100
# 50000/50000 [==============================] - 6s 114us/sample - loss: 0.8082 - accuracy: 0.7124 - val_loss: 1.5347 - val_accuracy: 0.5224
# Epoch 40/100
# 50000/50000 [==============================] - 6s 114us/sample - loss: 0.7918 - accuracy: 0.7190 - val_loss: 1.5750 - val_accuracy: 0.5293
# Epoch 41/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.7855 - accuracy: 0.7195 - val_loss: 1.6421 - val_accuracy: 0.5114
# Epoch 42/100
# 50000/50000 [==============================] - 6s 112us/sample - loss: 0.7668 - accuracy: 0.7268 - val_loss: 1.5912 - val_accuracy: 0.5166
# Epoch 43/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.7575 - accuracy: 0.7304 - val_loss: 1.6051 - val_accuracy: 0.5272
# Epoch 44/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 0.7463 - accuracy: 0.7328 - val_loss: 1.6447 - val_accuracy: 0.5295
# Epoch 45/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.7258 - accuracy: 0.7410 - val_loss: 1.6558 - val_accuracy: 0.5217
# Epoch 46/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.7076 - accuracy: 0.7472 - val_loss: 1.7036 - val_accuracy: 0.5186
# Epoch 47/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.6953 - accuracy: 0.7506 - val_loss: 1.7199 - val_accuracy: 0.5233
# Epoch 48/100
# 50000/50000 [==============================] - 6s 112us/sample - loss: 0.6914 - accuracy: 0.7522 - val_loss: 1.7033 - val_accuracy: 0.5263
# Epoch 49/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.6743 - accuracy: 0.7606 - val_loss: 1.8026 - val_accuracy: 0.5079
# Epoch 50/100
# 50000/50000 [==============================] - 6s 116us/sample - loss: 0.6630 - accuracy: 0.7644 - val_loss: 1.7589 - val_accuracy: 0.5174
# Epoch 51/100
# 50000/50000 [==============================] - 6s 113us/sample - loss: 0.6510 - accuracy: 0.7665 - val_loss: 1.7957 - val_accuracy: 0.5100
# Epoch 52/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.6612 - accuracy: 0.7640 - val_loss: 1.7966 - val_accuracy: 0.5133
# Epoch 53/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.6231 - accuracy: 0.7765 - val_loss: 1.8460 - val_accuracy: 0.5124
# Epoch 54/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.6107 - accuracy: 0.7815 - val_loss: 1.8556 - val_accuracy: 0.5186
# Epoch 55/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.6001 - accuracy: 0.7830 - val_loss: 1.9437 - val_accuracy: 0.5023
# Epoch 56/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.5862 - accuracy: 0.7891 - val_loss: 1.8603 - val_accuracy: 0.5190
# Epoch 57/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.5830 - accuracy: 0.7896 - val_loss: 2.0279 - val_accuracy: 0.5010
# Epoch 58/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.5692 - accuracy: 0.7972 - val_loss: 2.0090 - val_accuracy: 0.5139
# Epoch 59/100
# 50000/50000 [==============================] - 5s 105us/sample - loss: 0.5654 - accuracy: 0.7965 - val_loss: 1.9865 - val_accuracy: 0.5084
# Epoch 60/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.5383 - accuracy: 0.8084 - val_loss: 2.0043 - val_accuracy: 0.5116
# Epoch 61/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.5532 - accuracy: 0.8038 - val_loss: 2.0031 - val_accuracy: 0.5116
# Epoch 62/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.5248 - accuracy: 0.8113 - val_loss: 2.1367 - val_accuracy: 0.5007
# Epoch 63/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.5336 - accuracy: 0.8078 - val_loss: 2.0664 - val_accuracy: 0.5067
# Epoch 64/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.5277 - accuracy: 0.8100 - val_loss: 2.1583 - val_accuracy: 0.5042
# Epoch 65/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.5057 - accuracy: 0.8179 - val_loss: 2.1413 - val_accuracy: 0.5075
# Epoch 66/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.4930 - accuracy: 0.8231 - val_loss: 2.2304 - val_accuracy: 0.5003
# Epoch 67/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.4981 - accuracy: 0.8209 - val_loss: 2.2810 - val_accuracy: 0.4992
# Epoch 68/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 0.4862 - accuracy: 0.8247 - val_loss: 2.1918 - val_accuracy: 0.5067
# Epoch 69/100
# 50000/50000 [==============================] - 5s 110us/sample - loss: 0.4757 - accuracy: 0.8288 - val_loss: 2.3026 - val_accuracy: 0.4972
# Epoch 70/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.4607 - accuracy: 0.8327 - val_loss: 2.3134 - val_accuracy: 0.5044
# Epoch 71/100
# 50000/50000 [==============================] - 6s 112us/sample - loss: 0.4448 - accuracy: 0.8399 - val_loss: 2.3452 - val_accuracy: 0.5033
# Epoch 72/100
# 50000/50000 [==============================] - 6s 114us/sample - loss: 0.4636 - accuracy: 0.8328 - val_loss: 2.3421 - val_accuracy: 0.5031
# Epoch 73/100
# 50000/50000 [==============================] - 5s 106us/sample - loss: 0.4565 - accuracy: 0.8360 - val_loss: 2.4238 - val_accuracy: 0.5037
# Epoch 74/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.4457 - accuracy: 0.8420 - val_loss: 2.4313 - val_accuracy: 0.5000
# Epoch 75/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.4223 - accuracy: 0.8481 - val_loss: 2.4825 - val_accuracy: 0.4967
# Epoch 76/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.4372 - accuracy: 0.8416 - val_loss: 2.4427 - val_accuracy: 0.5040
# Epoch 77/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.4191 - accuracy: 0.8490 - val_loss: 2.5473 - val_accuracy: 0.4987
# Epoch 78/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.4215 - accuracy: 0.8488 - val_loss: 2.5858 - val_accuracy: 0.4991
# Epoch 79/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.4108 - accuracy: 0.8526 - val_loss: 2.5476 - val_accuracy: 0.4999
# Epoch 80/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.3942 - accuracy: 0.8578 - val_loss: 2.7470 - val_accuracy: 0.4955
# Epoch 81/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.3958 - accuracy: 0.8568 - val_loss: 2.6511 - val_accuracy: 0.5039
# Epoch 82/100
# 50000/50000 [==============================] - 5s 104us/sample - loss: 0.3879 - accuracy: 0.8610 - val_loss: 2.6979 - val_accuracy: 0.4968
# Epoch 83/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 0.3726 - accuracy: 0.8663 - val_loss: 2.7351 - val_accuracy: 0.4979
# Epoch 84/100
# 50000/50000 [==============================] - 6s 116us/sample - loss: 0.3655 - accuracy: 0.8697 - val_loss: 2.8132 - val_accuracy: 0.4995
# Epoch 85/100
# 50000/50000 [==============================] - 5s 110us/sample - loss: 0.3774 - accuracy: 0.8622 - val_loss: 2.8283 - val_accuracy: 0.4952
# Epoch 86/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.3751 - accuracy: 0.8639 - val_loss: 2.9109 - val_accuracy: 0.5021
# Epoch 87/100
# 50000/50000 [==============================] - 5s 110us/sample - loss: 0.3663 - accuracy: 0.8667 - val_loss: 2.8356 - val_accuracy: 0.4985
# Epoch 88/100
# 50000/50000 [==============================] - 5s 110us/sample - loss: 0.3676 - accuracy: 0.8680 - val_loss: 2.9527 - val_accuracy: 0.4974
# Epoch 89/100
# 50000/50000 [==============================] - 6s 110us/sample - loss: 0.3703 - accuracy: 0.8659 - val_loss: 2.9901 - val_accuracy: 0.4932
# Epoch 90/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.3488 - accuracy: 0.8731 - val_loss: 2.9201 - val_accuracy: 0.4998
# Epoch 91/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.3233 - accuracy: 0.8837 - val_loss: 3.0282 - val_accuracy: 0.4970
# Epoch 92/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.3268 - accuracy: 0.8839 - val_loss: 2.9411 - val_accuracy: 0.4970
# Epoch 93/100
# 50000/50000 [==============================] - 6s 113us/sample - loss: 0.3406 - accuracy: 0.8771 - val_loss: 2.9756 - val_accuracy: 0.5003
# Epoch 94/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.3624 - accuracy: 0.8691 - val_loss: 3.0119 - val_accuracy: 0.4974
# Epoch 95/100
# 50000/50000 [==============================] - 5s 109us/sample - loss: 0.3354 - accuracy: 0.8785 - val_loss: 3.0561 - val_accuracy: 0.4933
# Epoch 96/100
# 50000/50000 [==============================] - 6s 121us/sample - loss: 0.3008 - accuracy: 0.8920 - val_loss: 3.1565 - val_accuracy: 0.4952
# Epoch 97/100
# 50000/50000 [==============================] - 6s 121us/sample - loss: 0.3055 - accuracy: 0.8895 - val_loss: 3.1628 - val_accuracy: 0.4967
# Epoch 98/100
# 50000/50000 [==============================] - 5s 108us/sample - loss: 0.3238 - accuracy: 0.8839 - val_loss: 3.2317 - val_accuracy: 0.4878
# Epoch 99/100
# 50000/50000 [==============================] - 5s 107us/sample - loss: 0.3129 - accuracy: 0.8878 - val_loss: 3.2624 - val_accuracy: 0.4905
# Epoch 100/100
# 50000/50000 [==============================] - 6s 111us/sample - loss: 0.2980 - accuracy: 0.8937 - val_loss: 3.2509 - val_accuracy: 0.4947

# %%
# 訓練模型並檢視驗證集的結果
import matplotlib.pyplot as plt

train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-440b80adb08b> in <module>
#       1 # 訓練模型並檢視驗證集的結果
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 train_loss = model.history.history["loss"]
#       5 valid_loss = model.history.history["val_loss"]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度
